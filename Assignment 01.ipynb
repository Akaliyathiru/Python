# %%
# Assignment-do coding according to get output which have mentioned into the commment.

# %%
# Q1) Welcome to Assignment-1
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
#Q2)Num1= 10
   #Num2= 30
   #Add= 40 
Num1=10
print("Num1=",Num1)
Num2=30
print("Num2=",Num2)
Add=Num1+Num2
print("Add=",Add)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
#Enter the BMI Index:34
#Very Overweight
BMI=int (input("Enter the BMI Index:"))
if(BMI<18.5):
    print("Under weight")
elif(BMI>=18.5 and BMI<24.9):
    print("Healthy weight")
elif(BMI>25 and BMI<29.9):
    print("Over weight")
elif(BMI>30 and BMI<=40):
    print("Obese")
else:
    print("Severe obese")
# Out:
# Enter the BMI Index: 56
# Severe obese
