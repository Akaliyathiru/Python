# %%
# output need to be exactly what is mentioned in comment

# %%
#Mars Tech
print("Mars Tech")
# Out:
# Mars Tech

# %%
#Enter your institute name? : Mars Tech
IName=input("Enter your institute name? :")
# Out:
# Enter your institute name? : Mars Tech

# %%
#Enter your name: Raj
#Enter your age: 15
#Enter your school name: Guru school
#Enter your degree: B.E CSE
Name=input("Enter your name :")
age=input("Enter your age :")
school_name=input("Enter your school name :")
degree=input("Enter your degree :")
# Out:
# Enter your name : Raj
# Enter your age : 15
# Enter your school name : Guru School
# Enter your degree : B.E CSE

# %%
#a = 43
#b = 34
#add = 77
a=int(input("a="))
b=int(input("b="))
add=a+b
print("add=",add)
# Out:
# a= 43
# b= 34
# add= 77

# %%
#a = 43
#b = 34
#Sub = 9
a=int(input("a="))
b=int(input("b="))
sub=a-b
print("sub=",sub)
# Out:
# a= 43
# b= 34
# sub= 9

# %%
#a = 63
#b = 97
#Mul = 6111
a=int(input("a="))
b=int(input("b="))
Mul=a*b
print("Mul=",Mul)
# Out:
# a= 63
# b= 97
# Mul= 6111

# %%
#a = 76
#b = 31
#Float Div = 2.4516129032258065
a=int(input("a="))
b=int(input("b="))
FloatDiv=a/b
print("Float Div=",FloatDiv)
# Out:
# a= 76
# b= 31
# Float Div= 2.4516129032258065

# %%
#a = 76
#b = 31
#Floor Div = 2
a=int(input("a="))
b=int(input("b="))
FloorDiv=a//b
print("Floor Div=",FloorDiv)
# Out:
# a= 76
# b= 31
# Floor Div= 2

# %%
#a = 76
#b = 31
#Modulo = 14
a=int(input("a="))
b=int(input("b="))
Modulo=a%b
print("Modulo=",Modulo)
# Out:
# a= 76
# b= 31
# Modulo= 14

# %%
#a = 4
#b = 4
#Power = 256
a=int(input("a="))
b=int(input("b="))
Power=a**b
print("Power=",Power)
# Out:
# a= 4
# b= 4
# Power= 256
